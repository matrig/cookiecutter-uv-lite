# %% [markdown]
# # Exploratory Data Analysis
#
# {% set package_name = cookiecutter.project_name|lower|replace('-', '_') -%}
# This notebook demonstrates basic data exploration using pandas and numpy.

# %%
import pandas as pd
import numpy as np

from {{ package_name }}.utils import load_sample_data

# Load sample data
df = load_sample_data()
print(f"✓ Loaded dataset with shape: {df.shape}")

# %% [markdown]
# ## Quick Overview

# %%
# First few rows
df.head()

# %%
# Data types and info
df.info()

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ## Group Analysis

# %%
# Summary statistics by category
df.groupby('category').agg({
    'x': ['mean', 'std'],
    'y': ['mean', 'std', 'min', 'max']
})

# %% [markdown]
# ## Correlation Analysis

# %%
# Correlation between numeric columns
df.select_dtypes(include=[np.number]).corr()

# %% [markdown]
# ## Next Steps
#
# - See `02-visualization.ipynb` for plotting examples
# - Add your own data to the `data/` directory
# - Move reusable functions to `{{ package_name }}/utils.py`
